# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib as mpl
mpl.rc("savefig",dpi=150)

img=cv2.imread('CGTrab1.tiff',0)
rows,cols=img.shape
plt.imshow(img,cmap=plt.get_cmap('gray'),vmin=0,vmax=255)
plt.title('ImagemOriginal')
plt.show()
